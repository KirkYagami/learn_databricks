# %%
# spark

# %%
# spark.version
# Out:
# '4.1.0'

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /databricks/python3/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests) (2025.1.31)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# import requests
# requests.get("https://www.cnn.com").text

# %%
# spark

# %%
# import reverse_geocoder as rg
# coordinates = (51.5214588,-0.1729636),(9.936033, 76.259952),(37.38605,-122.08385)
# rg.search(coordinates)

# %% [markdown]
# ## Project

# %%
# Mount ADLS Gen2
# Required each time the cluster is restarted which should be only on the first notebook as they run in order

tiers = ["bronze", "silver", "gold"]
adls_paths = {tier: f"abfss://{tier}@adlsnikhildev.dfs.core.windows.net/" for tier in tiers}

# Accessing paths
bronze_adls = adls_paths["bronze"]
silver_adls = adls_paths["silver"]
gold_adls = adls_paths["gold"] 

dbutils.fs.ls(bronze_adls)
dbutils.fs.ls(silver_adls)
dbutils.fs.ls(gold_adls)
# Out:
# []

# %%
import requests
import json
from datetime import date, timedelta

# %%
start_date = date.today() - timedelta(days=1)
end_date = date.today()

# %%
print(start_date, end_date)
# Out:
# 2026-06-05 2026-06-06

# %%
# Construct the API URL with start and end dates provided by Data Factory, formatted for geojson output.
url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"

try:
    # Make the GET request to fetch data
    response = requests.get(url)

    # Check if the request was successful
    response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
    data = response.json().get('features', [])

    if not data:
        print("No data returned for the specified date range.")
    else:
        # Specify the ADLS path
        file_path = f"{bronze_adls}/{start_date}_earthquake_data.json"

        # Save the JSON data
        json_data = json.dumps(data, indent=4)
        dbutils.fs.put(file_path, json_data, overwrite=True)
        print(f"Data successfully saved to {file_path}")
except requests.exceptions.RequestException as e:
    print(f"Error fetching data from API: {e}")
# Out:
# Wrote 427152 bytes.
# Data successfully saved to abfss://bronze@adlsnikhildev.dfs.core.windows.net//2026-06-05_earthquake_data.json

# %%
print(json_data)
# Out:
# [
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.94,
#             "place": "13 km ENE of Honaunau-Napoopoo, Hawaii",
#             "time": 1780703997200,
#             "updated": 1780704259380,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/hv74977022",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv74977022&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 58,
#             "net": "hv",
#             "code": "74977022",
#             "ids": ",hv74977022,",
#             "sources": ",hv,",
#             "types": ",origin,phase-data,",
#             "nst": 30,
#             "dmin": 0.03817,
#             "rms": 0.280000001,
#             "gap": 121,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 1.9 - 13 km ENE of Honaunau-Napoopoo, Hawaii"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -155.7431640625,
#                 19.5060005187988,
#                 6.03000020980835
#             ]
#         },
#         "id": "hv74977022"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.3,
#             "place": "24 km S of Midland, Texas",
#             "time": 1780703903389,
#             "updated": 1780704163495,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/tx2026lajfxs",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2026lajfxs&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 26,
#             "net": "tx",
#             "code": "2026lajfxs",
#             "ids": ",tx2026lajfxs,",
#             "sources": ",tx,",
#             "types": ",origin,phase-data,",
#             "nst": 35,
#             "dmin": 0.1,
#             "rms": 0.4,
#             "gap": 83,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.3 - 24 km S of Midland, Texas"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -102.03,
#                 31.782,
#                 2.2703
#             ]
#         },
#         "id": "tx2026lajfxs"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 0.69,
#             "place": "11 km NW of The Geysers, CA",
#             "time": 1780703672510,
#             "updated": 1780703770790,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371591",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371591&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 7,
#             "net": "nc",
#             "code": "75371591",
#             "ids": ",nc75371591,",
#             "sources": ",nc,",
#             "types": ",nearby-cities,origin,phase-data,",
#             "nst": 14,
#             "dmin": 0.01238,
#             "rms": 0.02,
#             "gap": 128,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 0.7 - 11 km NW of The Geysers, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -122.847503662109,
#                 38.8466682434082,
#                 1.46000003814697
#             ]
#         },
#         "id": "nc75371591"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 0.74,
#             "place": "8 km WNW of Cobb, CA",
#             "time": 1780703666740,
#             "updated": 1780703760862,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371586",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371586&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 8,
#             "net": "nc",
#             "code": "75371586",
#             "ids": ",nc75371586,",
#             "sources": ",nc,",
#             "types": ",nearby-cities,origin,phase-data,",
#             "nst": 11,
#             "dmin": 0.01353,
#             "rms": 0.01,
#             "gap": 60,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 0.7 - 8 km WNW of Cobb, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -122.807830810547,
#                 38.8368339538574,
#                 1.89999997615814
#             ]
#         },
#         "id": "nc75371586"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 0.25,
#             "place": "11 km WNW of Cobb, CA",
#             "time": 1780703171290,
#             "updated": 1780703265621,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371581",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371581&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 1,
#             "net": "nc",
#             "code": "75371581",
#             "ids": ",nc75371581,",
#             "sources": ",nc,",
#             "types": ",nearby-cities,origin,phase-data,",
#             "nst": 9,
#             "dmin": 0.0134,
#             "rms": 0.06,
#             "gap": 145,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 0.3 - 11 km WNW of Cobb, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -122.844169616699,
#                 38.8501663208008,
#                 2.9300000667572
#             ]
#         },
#         "id": "nc75371581"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 0.93,
#             "place": "69 km W of Nikolski, Alaska",
#             "time": 1780702898690,
#             "updated": 1780723940350,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94227028",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94227028&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 13,
#             "net": "av",
#             "code": "94227028",
#             "ids": ",av94227028,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 4,
#             "dmin": 0.02159,
#             "rms": 0.09,
#             "gap": 210,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 0.9 - 69 km W of Nikolski, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -169.878833333333,
#                 52.8426666666667,
#                 9.69
#             ]
#         },
#         "id": "av94227028"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 0.38,
#             "place": "11 km NW of The Geysers, CA",
#             "time": 1780702754950,
#             "updated": 1780702850766,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371571",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371571&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 2,
#             "net": "nc",
#             "code": "75371571",
#             "ids": ",nc75371571,",
#             "sources": ",nc,",
#             "types": ",nearby-cities,origin,phase-data,",
#             "nst": 9,
#             "dmin": 0.01216,
#             "rms": 0.02,
#             "gap": 127,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 0.4 - 11 km NW of The Geysers, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -122.847503662109,
#                 38.8463325500488,
#                 1.53999996185303
#             ]
#         },
#         "id": "nc75371571"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.2,
#             "place": "16 km ESE of Stanton, Texas",
#             "time": 1780702748252,
#             "updated": 1780704084556,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/tx2026laipil",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2026laipil&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 22,
#             "net": "tx",
#             "code": "2026laipil",
#             "ids": ",tx2026laipil,",
#             "sources": ",tx,",
#             "types": ",origin,phase-data,",
#             "nst": 15,
#             "dmin": 0,
#             "rms": 0.5,
#             "gap": 74,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.2 - 16 km ESE of Stanton, Texas"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -101.623,
#                 32.073,
#                 2.9226
#             ]
#         },
#         "id": "tx2026laipil"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.23,
#             "place": "68 km W of Nikolski, Alaska",
#             "time": 1780702539130,
#             "updated": 1780723759980,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94227023",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94227023&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 23,
#             "net": "av",
#             "code": "94227023",
#             "ids": ",av94227023,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 5,
#             "dmin": 0.01919,
#             "rms": 0.19,
#             "gap": 170,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.2 - 68 km W of Nikolski, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -169.8635,
#                 52.8228333333333,
#                 8.52
#             ]
#         },
#         "id": "av94227023"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 0.42,
#             "place": "11 km NW of The Geysers, CA",
#             "time": 1780701782110,
#             "updated": 1780701880859,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371561",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371561&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 3,
#             "net": "nc",
#             "code": "75371561",
#             "ids": ",nc75371561,",
#             "sources": ",nc,",
#             "types": ",nearby-cities,origin,phase-data,",
#             "nst": 11,
#             "dmin": 0.01229,
#             "rms": 0.03,
#             "gap": 103,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 0.4 - 11 km NW of The Geysers, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -122.84716796875,
#                 38.8468322753906,
#                 1.5
#             ]
#         },
#         "id": "nc75371561"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 2.31,
#             "place": "23 km SSE of Somes Bar, CA",
#             "time": 1780701524090,
#             "updated": 1780708042359,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371556",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371556&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 82,
#             "net": "nc",
#             "code": "75371556",
#             "ids": ",nc75371556,",
#             "sources": ",nc,",
#             "types": ",nearby-cities,origin,phase-data,scitech-link,",
#             "nst": 7,
#             "dmin": 0.1379,
#             "rms": 0.05,
#             "gap": 119,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 2.3 - 23 km SSE of Somes Bar, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -123.338996887207,
#                 41.1938323974609,
#                 36.2700004577637
#             ]
#         },
#         "id": "nc75371556"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.94,
#             "place": "9 km SSE of Honaunau-Napoopoo, Hawaii",
#             "time": 1780699771060,
#             "updated": 1780699990100,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/hv74976997",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv74976997&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 58,
#             "net": "hv",
#             "code": "74976997",
#             "ids": ",hv74976997,",
#             "sources": ",hv,",
#             "types": ",origin,phase-data,",
#             "nst": 10,
#             "dmin": 0.1847,
#             "rms": 0.140000001,
#             "gap": 203,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 1.9 - 9 km SSE of Honaunau-Napoopoo, Hawaii"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -155.839340209961,
#                 19.3713340759277,
#                 23.8999996185303
#             ]
#         },
#         "id": "hv74976997"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 0.33,
#             "place": "70 km W of Nikolski, Alaska",
#             "time": 1780699758970,
#             "updated": 1780723488660,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94226958",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94226958&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 2,
#             "net": "av",
#             "code": "94226958",
#             "ids": ",av94226958,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 4,
#             "dmin": 0.004847,
#             "rms": 0.14,
#             "gap": 162,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 0.3 - 70 km W of Nikolski, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -169.892166666667,
#                 52.828,
#                 10.95
#             ]
#         },
#         "id": "av94226958"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 2,
#             "place": "59 km S of Whites City, New Mexico",
#             "time": 1780699709632,
#             "updated": 1780699935139,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/tx2026lagvvo",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2026lagvvo&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 62,
#             "net": "tx",
#             "code": "2026lagvvo",
#             "ids": ",tx2026lagvvo,",
#             "sources": ",tx,",
#             "types": ",origin,phase-data,",
#             "nst": 33,
#             "dmin": 0,
#             "rms": 0.5,
#             "gap": 73,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 2.0 - 59 km S of Whites City, New Mexico"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -104.404,
#                 31.636,
#                 4.0358
#             ]
#         },
#         "id": "tx2026lagvvo"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 0.76,
#             "place": "8 km NW of The Geysers, CA",
#             "time": 1780699540500,
#             "updated": 1780699635182,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371551",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371551&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 9,
#             "net": "nc",
#             "code": "75371551",
#             "ids": ",nc75371551,",
#             "sources": ",nc,",
#             "types": ",nearby-cities,origin,phase-data,",
#             "nst": 15,
#             "dmin": 0.01079,
#             "rms": 0.01,
#             "gap": 56,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 0.8 - 8 km NW of The Geysers, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -122.815498352051,
#                 38.8333320617676,
#                 1.87999999523163
#             ]
#         },
#         "id": "nc75371551"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.97,
#             "place": "8 km SW of Fort Bragg, CA",
#             "time": 1780699419910,
#             "updated": 1780703244825,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371546",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371546&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 60,
#             "net": "nc",
#             "code": "75371546",
#             "ids": ",nc75371546,",
#             "sources": ",nc,",
#             "types": ",nearby-cities,origin,phase-data,scitech-link,",
#             "nst": 8,
#             "dmin": 0.1315,
#             "rms": 0.01,
#             "gap": 210,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 2.0 - 8 km SW of Fort Bragg, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -123.873664855957,
#                 39.4000015258789,
#                 1.95000004768372
#             ]
#         },
#         "id": "nc75371546"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 3.8,
#             "place": "57 km S of Whites City, New Mexico",
#             "time": 1780699210540,
#             "updated": 1780707349478,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/tx2026lagqgm",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2026lagqgm&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": 4.519,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 222,
#             "net": "tx",
#             "code": "2026lagqgm",
#             "ids": ",us7000sr0k,tx2026lagqgm,",
#             "sources": ",us,tx,",
#             "types": ",origin,phase-data,shakemap,",
#             "nst": 54,
#             "dmin": 0,
#             "rms": 0.2,
#             "gap": 66,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 3.8 - 57 km S of Whites City, New Mexico"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -104.395,
#                 31.661,
#                 6.0999
#             ]
#         },
#         "id": "tx2026lagqgm"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.7,
#             "place": "57 km S of Whites City, New Mexico",
#             "time": 1780698821782,
#             "updated": 1780699039524,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/tx2026lagkox",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2026lagkox&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 44,
#             "net": "tx",
#             "code": "2026lagkox",
#             "ids": ",tx2026lagkox,",
#             "sources": ",tx,",
#             "types": ",origin,phase-data,",
#             "nst": 32,
#             "dmin": 0,
#             "rms": 0.4,
#             "gap": 88,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.7 - 57 km S of Whites City, New Mexico"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -104.378,
#                 31.658,
#                 3.7201
#             ]
#         },
#         "id": "tx2026lagkox"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.22,
#             "place": "10 km S of Idyllwild, CA",
#             "time": 1780698417660,
#             "updated": 1780699067910,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ci41481200",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41481200&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 23,
#             "net": "ci",
#             "code": "41481200",
#             "ids": ",ci41481200,",
#             "sources": ",ci,",
#             "types": ",focal-mechanism,nearby-cities,origin,phase-data,scitech-link,",
#             "nst": 50,
#             "dmin": 0.04573,
#             "rms": 0.17,
#             "gap": 36,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.2 - 10 km S of Idyllwild, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -116.7225,
#                 33.6478333333333,
#                 15.38
#             ]
#         },
#         "id": "ci41481200"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 4.7,
#             "place": "Izu Islands, Japan region",
#             "time": 1780698254493,
#             "updated": 1780702341040,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000sr0h",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000sr0h&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 340,
#             "net": "us",
#             "code": "7000sr0h",
#             "ids": ",us7000sr0h,",
#             "sources": ",us,",
#             "types": ",origin,phase-data,",
#             "nst": 44,
#             "dmin": 5.378,
#             "rms": 0.78,
#             "gap": 100,
#             "magType": "mb",
#             "type": "earthquake",
#             "title": "M 4.7 - Izu Islands, Japan region"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 141.6762,
#                 31.6019,
#                 10
#             ]
#         },
#         "id": "us7000sr0h"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.27,
#             "place": "2 km SSE of Adak, Alaska",
#             "time": 1780698206260,
#             "updated": 1780723187270,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94226913",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94226913&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 25,
#             "net": "av",
#             "code": "94226913",
#             "ids": ",av94226913,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 7,
#             "dmin": 0.1271,
#             "rms": 0.1,
#             "gap": 280,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.3 - 2 km SSE of Adak, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -176.621833333333,
#                 51.8538333333333,
#                 4.95
#             ]
#         },
#         "id": "av94226913"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 5,
#             "place": "Kermadec Islands region",
#             "time": 1780698122934,
#             "updated": 1780700099040,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000sr0g",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000sr0g&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 385,
#             "net": "us",
#             "code": "7000sr0g",
#             "ids": ",us7000sr0g,",
#             "sources": ",us,",
#             "types": ",origin,phase-data,",
#             "nst": 25,
#             "dmin": 0.935,
#             "rms": 1.27,
#             "gap": 166,
#             "magType": "mb",
#             "type": "earthquake",
#             "title": "M 5.0 - Kermadec Islands region"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -176.8622,
#                 -29.3155,
#                 10
#             ]
#         },
#         "id": "us7000sr0g"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 4.5,
#             "place": "30 km NNE of Nasinu, Fiji",
#             "time": 1780697291021,
#             "updated": 1780698696040,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000sr0c",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000sr0c&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 312,
#             "net": "us",
#             "code": "7000sr0c",
#             "ids": ",us7000sr0c,",
#             "sources": ",us,",
#             "types": ",origin,phase-data,",
#             "nst": 59,
#             "dmin": 0.525,
#             "rms": 0.89,
#             "gap": 126,
#             "magType": "mb",
#             "type": "earthquake",
#             "title": "M 4.5 - 30 km NNE of Nasinu, Fiji"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 178.6006,
#                 -17.8045,
#                 562.138
#             ]
#         },
#         "id": "us7000sr0c"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.42,
#             "place": "3 km WNW of Anderson Springs, CA",
#             "time": 1780697180550,
#             "updated": 1780701741648,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371541",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371541&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 31,
#             "net": "nc",
#             "code": "75371541",
#             "ids": ",nc75371541,",
#             "sources": ",nc,",
#             "types": ",nearby-cities,origin,phase-data,scitech-link,",
#             "nst": 18,
#             "dmin": 0.01412,
#             "rms": 0.03,
#             "gap": 82,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 1.4 - 3 km WNW of Anderson Springs, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -122.71866607666,
#                 38.7836685180664,
#                 1.83000004291534
#             ]
#         },
#         "id": "nc75371541"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 4.7,
#             "place": "43 km SE of Severo-Kuril\u2019sk, Russia",
#             "time": 1780696926374,
#             "updated": 1780701624040,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000sr0b",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000sr0b&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 340,
#             "net": "us",
#             "code": "7000sr0b",
#             "ids": ",us7000sr0b,",
#             "sources": ",us,",
#             "types": ",origin,phase-data,",
#             "nst": 62,
#             "dmin": 2.773,
#             "rms": 0.66,
#             "gap": 111,
#             "magType": "mb",
#             "type": "earthquake",
#             "title": "M 4.7 - 43 km SE of Severo-Kuril\u2019sk, Russia"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 156.5979,
#                 50.425,
#                 69.461
#             ]
#         },
#         "id": "us7000sr0b"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.13,
#             "place": "5 km SSW of Redlands, CA",
#             "time": 1780696648910,
#             "updated": 1780696862032,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/ci41481184",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41481184&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 20,
#             "net": "ci",
#             "code": "41481184",
#             "ids": ",ci41481184,",
#             "sources": ",ci,",
#             "types": ",nearby-cities,origin,phase-data,scitech-link,",
#             "nst": 27,
#             "dmin": 0.07188,
#             "rms": 0.14,
#             "gap": 34,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.1 - 5 km SSW of Redlands, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -117.209833333333,
#                 34.0125,
#                 5.72
#             ]
#         },
#         "id": "ci41481184"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.03,
#             "place": "13 km NW of The Geysers, CA",
#             "time": 1780696619170,
#             "updated": 1780696713869,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371536",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371536&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 16,
#             "net": "nc",
#             "code": "75371536",
#             "ids": ",nc75371536,",
#             "sources": ",nc,",
#             "types": ",nearby-cities,origin,phase-data,",
#             "nst": 12,
#             "dmin": 0.005791,
#             "rms": 0.02,
#             "gap": 90,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 1.0 - 13 km NW of The Geysers, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -122.877334594727,
#                 38.8414993286133,
#                 2.33999991416931
#             ]
#         },
#         "id": "nc75371536"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 2,
#             "place": "57 km S of Whites City, New Mexico",
#             "time": 1780696045218,
#             "updated": 1780696270859,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/tx2026laewtq",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2026laewtq&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 62,
#             "net": "tx",
#             "code": "2026laewtq",
#             "ids": ",tx2026laewtq,",
#             "sources": ",tx,",
#             "types": ",origin,phase-data,",
#             "nst": 33,
#             "dmin": 0.1,
#             "rms": 0.4,
#             "gap": 70,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 2.0 - 57 km S of Whites City, New Mexico"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -104.362,
#                 31.657,
#                 4.7131
#             ]
#         },
#         "id": "tx2026laewtq"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": -0.17,
#             "place": "5 km W of Dutch Harbor, Alaska",
#             "time": 1780695568530,
#             "updated": 1780722915840,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94226863",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94226863&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 0,
#             "net": "av",
#             "code": "94226863",
#             "ids": ",av94226863,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 7,
#             "dmin": 0.0357,
#             "rms": 0.13,
#             "gap": 147,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M -0.2 - 5 km W of Dutch Harbor, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -166.630333333333,
#                 53.8971666666667,
#                 7.05
#             ]
#         },
#         "id": "av94226863"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 0.48,
#             "place": "87 km W of Karluk, Alaska",
#             "time": 1780695399200,
#             "updated": 1780722765540,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94226858",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94226858&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 4,
#             "net": "av",
#             "code": "94226858",
#             "ids": ",av94226858,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 6,
#             "dmin": 0.1958,
#             "rms": 0.09,
#             "gap": 227,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 0.5 - 87 km W of Karluk, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -155.91,
#                 57.656,
#                 4.19
#             ]
#         },
#         "id": "av94226858"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.44,
#             "place": "2 km SE of Adak, Alaska",
#             "time": 1780695325330,
#             "updated": 1780722614390,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94226853",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94226853&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 32,
#             "net": "av",
#             "code": "94226853",
#             "ids": ",av94226853,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 7,
#             "dmin": 0.123,
#             "rms": 0.1,
#             "gap": 275,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.4 - 2 km SE of Adak, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -176.6085,
#                 51.8573333333333,
#                 4.57
#             ]
#         },
#         "id": "av94226853"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 0.66,
#             "place": "10 km WNW of Cobb, CA",
#             "time": 1780695164310,
#             "updated": 1780695258720,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371531",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371531&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 7,
#             "net": "nc",
#             "code": "75371531",
#             "ids": ",nc75371531,",
#             "sources": ",nc,",
#             "types": ",nearby-cities,origin,phase-data,",
#             "nst": 7,
#             "dmin": 0.005833,
#             "rms": 0.02,
#             "gap": 175,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 0.7 - 10 km WNW of Cobb, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -122.825836181641,
#                 38.8601684570312,
#                 1.14999997615814
#             ]
#         },
#         "id": "nc75371531"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": -0.36,
#             "place": "65 km ENE of Pedro Bay, Alaska",
#             "time": 1780694953010,
#             "updated": 1780722193760,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94226838",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94226838&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 0,
#             "net": "av",
#             "code": "94226838",
#             "ids": ",av94226838,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 4,
#             "dmin": 0.00438,
#             "rms": 0.13,
#             "gap": 216,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M -0.4 - 65 km ENE of Pedro Bay, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -153.017,
#                 60.012,
#                 2.89
#             ]
#         },
#         "id": "av94226838"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.45,
#             "place": "3 km E of Adak, Alaska",
#             "time": 1780694594690,
#             "updated": 1780722104480,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av93061704",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av93061704&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 32,
#             "net": "av",
#             "code": "93061704",
#             "ids": ",av93061704,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 8,
#             "dmin": 0.1035,
#             "rms": 0.14,
#             "gap": 169,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.5 - 3 km E of Adak, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -176.5785,
#                 51.8775,
#                 3.07
#             ]
#         },
#         "id": "av93061704"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.09,
#             "place": "2 km SE of Adak, Alaska",
#             "time": 1780694582200,
#             "updated": 1780721984270,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94226823",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94226823&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 18,
#             "net": "av",
#             "code": "94226823",
#             "ids": ",av94226823,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 6,
#             "dmin": 0.1225,
#             "rms": 0.04,
#             "gap": 275,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.1 - 2 km SE of Adak, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -176.611333333333,
#                 51.8578333333333,
#                 4.62
#             ]
#         },
#         "id": "av94226823"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 2.21,
#             "place": "4 km E of Adak, Alaska",
#             "time": 1780694194400,
#             "updated": 1780721562700,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av93061699",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av93061699&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 75,
#             "net": "av",
#             "code": "93061699",
#             "ids": ",av93061699,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 7,
#             "dmin": 0.1009,
#             "rms": 0.19,
#             "gap": 174,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 2.2 - 4 km E of Adak, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -176.568166666667,
#                 51.8811666666667,
#                 1.03
#             ]
#         },
#         "id": "av93061699"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 2.15,
#             "place": "3 km E of Adak, Alaska",
#             "time": 1780694189650,
#             "updated": 1780721352480,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94226808",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94226808&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 71,
#             "net": "av",
#             "code": "94226808",
#             "ids": ",av94226808,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 14,
#             "dmin": 0.1069,
#             "rms": 0.12,
#             "gap": 159,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 2.2 - 3 km E of Adak, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -176.58,
#                 51.874,
#                 3.1
#             ]
#         },
#         "id": "av94226808"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 2.72,
#             "place": "12 km W of Petrolia, CA",
#             "time": 1780694009170,
#             "updated": 1780699939472,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371526",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371526&format=geojson",
#             "felt": 1,
#             "cdi": 2.2,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 114,
#             "net": "nc",
#             "code": "75371526",
#             "ids": ",nc75371526,",
#             "sources": ",nc,",
#             "types": ",dyfi,nearby-cities,origin,phase-data,scitech-link,",
#             "nst": 14,
#             "dmin": 0.07664,
#             "rms": 0.11,
#             "gap": 301,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 2.7 - 12 km W of Petrolia, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -124.424331665039,
#                 40.3328323364258,
#                 16.6399993896484
#             ]
#         },
#         "id": "nc75371526"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.05,
#             "place": "7 km NW of The Geysers, CA",
#             "time": 1780693974240,
#             "updated": 1780694068657,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75371521",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75371521&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 17,
#             "net": "nc",
#             "code": "75371521",
#             "ids": ",nc75371521,",
#             "sources": ",nc,",
# ...
#             "updated": 1780703291610,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/hv74976502",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv74976502&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 29,
#             "net": "hv",
#             "code": "74976502",
#             "ids": ",hv74976502,",
#             "sources": ",hv,",
#             "types": ",origin,phase-data,",
#             "nst": 36,
#             "dmin": 0.03404,
#             "rms": 0.11,
#             "gap": 190,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.4 - 12 km ENE of P\u0101hala, Hawaii"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -155.361666666667,
#                 19.234,
#                 33.21
#             ]
#         },
#         "id": "hv74976502"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 3.2,
#             "place": "138 km W of Whitehorse, Canada",
#             "time": 1780621063289,
#             "updated": 1780674246756,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000sqs1",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000sqs1&format=geojson",
#             "felt": 3,
#             "cdi": 2.5,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 158,
#             "net": "us",
#             "code": "7000sqs1",
#             "ids": ",us7000sqs1,aka2026lajint,",
#             "sources": ",us,ak,",
#             "types": ",dyfi,origin,phase-data,",
#             "nst": 30,
#             "dmin": 0.086,
#             "rms": 0.73,
#             "gap": 66,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 3.2 - 138 km W of Whitehorse, Canada"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -137.5845,
#                 60.7497,
#                 10
#             ]
#         },
#         "id": "us7000sqs1"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.58,
#             "place": "1 km SE of Sechelt, Canada",
#             "time": 1780620882710,
#             "updated": 1780683092820,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/uw714006381",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw714006381&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 38,
#             "net": "uw",
#             "code": "714006381",
#             "ids": ",uw714006381,",
#             "sources": ",uw,",
#             "types": ",origin,phase-data,",
#             "nst": 10,
#             "dmin": 0.5415,
#             "rms": 0.2,
#             "gap": 227,
#             "magType": "md",
#             "type": "explosion",
#             "title": "M 1.6 Explosion - 1 km SE of Sechelt, Canada"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -123.7485,
#                 49.4673333333333,
#                 -0.08
#             ]
#         },
#         "id": "uw714006381"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 0.3,
#             "place": "66 km W of Nikolski, Alaska",
#             "time": 1780619849090,
#             "updated": 1780692518960,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94225033",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94225033&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 1,
#             "net": "av",
#             "code": "94225033",
#             "ids": ",av94225033,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 5,
#             "dmin": 0.04136,
#             "rms": 0.16,
#             "gap": 202,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 0.3 - 66 km W of Nikolski, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -169.838666666667,
#                 52.8466666666667,
#                 4.89
#             ]
#         },
#         "id": "av94225033"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.05,
#             "place": "66 km W of Nikolski, Alaska",
#             "time": 1780619805830,
#             "updated": 1780692248620,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94225028",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94225028&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 17,
#             "net": "av",
#             "code": "94225028",
#             "ids": ",av94225028,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 5,
#             "dmin": 0.04107,
#             "rms": 0.14,
#             "gap": 202,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.1 - 66 km W of Nikolski, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -169.839833333333,
#                 52.8471666666667,
#                 5.04
#             ]
#         },
#         "id": "av94225028"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.9,
#             "place": "12 km SSE of Volcano, Hawaii",
#             "time": 1780619709640,
#             "updated": 1780619929190,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/hv74976472",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv74976472&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 56,
#             "net": "hv",
#             "code": "74976472",
#             "ids": ",hv74976472,",
#             "sources": ",hv,",
#             "types": ",origin,phase-data,",
#             "nst": 38,
#             "dmin": 0.04296,
#             "rms": 0.219999999,
#             "gap": 138,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 1.9 - 12 km SSE of Volcano, Hawaii"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -155.202163696289,
#                 19.3325004577637,
#                 1.61000001430511
#             ]
#         },
#         "id": "hv74976472"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.3,
#             "place": "17 km SW of Falls City, Texas",
#             "time": 1780619687022,
#             "updated": 1780688528298,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/tx2026kyoskj",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2026kyoskj&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 26,
#             "net": "tx",
#             "code": "2026kyoskj",
#             "ids": ",tx2026kyoskj,",
#             "sources": ",tx,",
#             "types": ",origin,phase-data,",
#             "nst": 15,
#             "dmin": 0.1,
#             "rms": 0.1,
#             "gap": 71,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.3 - 17 km SW of Falls City, Texas"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -98.156,
#                 28.883,
#                 8.9471
#             ]
#         },
#         "id": "tx2026kyoskj"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.17,
#             "place": "67 km W of Nikolski, Alaska",
#             "time": 1780618411730,
#             "updated": 1780692128410,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/av94225003",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av94225003&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 21,
#             "net": "av",
#             "code": "94225003",
#             "ids": ",av94225003,",
#             "sources": ",av,",
#             "types": ",origin,phase-data,",
#             "nst": 5,
#             "dmin": 0.02687,
#             "rms": 0.22,
#             "gap": 186,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.2 - 67 km W of Nikolski, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -169.857,
#                 52.8371666666667,
#                 2.79
#             ]
#         },
#         "id": "av94225003"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.5,
#             "place": "50 km WNW of Aleneva, Alaska",
#             "time": 1780618182771,
#             "updated": 1780631238957,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/aka2026lahsnm",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=aka2026lahsnm&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 35,
#             "net": "ak",
#             "code": "a2026lahsnm",
#             "ids": ",aka2026lahsnm,",
#             "sources": ",ak,",
#             "types": ",origin,phase-data,",
#             "nst": 22,
#             "dmin": 0.5,
#             "rms": 0.5,
#             "gap": 115,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.5 - 50 km WNW of Aleneva, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -153.655,
#                 58.288,
#                 64.8
#             ]
#         },
#         "id": "aka2026lahsnm"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.24,
#             "place": "3 km S of Redwood Valley, CA",
#             "time": 1780618119900,
#             "updated": 1780623443057,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/nc75370986",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75370986&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 24,
#             "net": "nc",
#             "code": "75370986",
#             "ids": ",nc75370986,",
#             "sources": ",nc,",
#             "types": ",nearby-cities,origin,phase-data,scitech-link,",
#             "nst": 6,
#             "dmin": 0.07066,
#             "rms": 0.02,
#             "gap": 130,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 1.2 - 3 km S of Redwood Valley, CA"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -123.206169128418,
#                 39.2343330383301,
#                 4.53000020980835
#             ]
#         },
#         "id": "nc75370986"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.9,
#             "place": "25 km W of Ivanof Bay, Alaska",
#             "time": 1780617937837,
#             "updated": 1780631116679,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/aka2026lahozd",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=aka2026lahozd&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 56,
#             "net": "ak",
#             "code": "a2026lahozd",
#             "ids": ",aka2026lahozd,",
#             "sources": ",ak,",
#             "types": ",origin,phase-data,",
#             "nst": 14,
#             "dmin": 0.3,
#             "rms": 0.5,
#             "gap": 177,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.9 - 25 km W of Ivanof Bay, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -159.888,
#                 55.871,
#                 7.3
#             ]
#         },
#         "id": "aka2026lahozd"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.8,
#             "place": "4 km NNE of P\u0101hala, Hawaii",
#             "time": 1780617893920,
#             "updated": 1780618110570,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/hv74976462",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv74976462&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "automatic",
#             "tsunami": 0,
#             "sig": 50,
#             "net": "hv",
#             "code": "74976462",
#             "ids": ",hv74976462,",
#             "sources": ",hv,",
#             "types": ",origin,phase-data,",
#             "nst": 22,
#             "dmin": 0.05949,
#             "rms": 0.109999999,
#             "gap": 162,
#             "magType": "md",
#             "type": "earthquake",
#             "title": "M 1.8 - 4 km NNE of P\u0101hala, Hawaii"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -155.460327148438,
#                 19.2415008544922,
#                 31.4799995422363
#             ]
#         },
#         "id": "hv74976462"
#     },
#     {
#         "type": "Feature",
#         "properties": {
#             "mag": 1.8,
#             "place": "30 km ESE of Skwentna, Alaska",
#             "time": 1780617673493,
#             "updated": 1780631003329,
#             "tz": null,
#             "url": "https://earthquake.usgs.gov/earthquakes/eventpage/aka2026lahldq",
#             "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=aka2026lahldq&format=geojson",
#             "felt": null,
#             "cdi": null,
#             "mmi": null,
#             "alert": null,
#             "status": "reviewed",
#             "tsunami": 0,
#             "sig": 50,
#             "net": "ak",
#             "code": "a2026lahldq",
#             "ids": ",aka2026lahldq,",
#             "sources": ",ak,",
#             "types": ",origin,phase-data,",
#             "nst": 34,
#             "dmin": 0.3,
#             "rms": 0.6,
#             "gap": 63,
#             "magType": "ml",
#             "type": "earthquake",
#             "title": "M 1.8 - 30 km ESE of Skwentna, Alaska"
#         },
#         "geometry": {
#             "type": "Point",
#             "coordinates": [
#                 -150.838,
#                 61.91,
#                 69.2
#             ]
#         },
#         "id": "aka2026lahldq"
#     }
# ]

# %%
# Define output parameters to pass to Silver notebook
output_data = {
    "start_date": start_date.isoformat(),
    "end_date": end_date.isoformat(),
    "bronze_path": adls_paths["bronze"],
    "silver_path": adls_paths["silver"],
    "gold_path": adls_paths["gold"]
}

# Set task values for workflow
dbutils.jobs.taskValues.set(key="bronze_output", value=output_data)

print("Bronze notebook completed successfully!")
print(f"Output parameters: {output_data}")
# Out:
# Bronze notebook completed successfully!
# Output parameters: {'start_date': '2026-06-05', 'end_date': '2026-06-06', 'bronze_path': 'abfss://bronze@adlsnikhildev.dfs.core.windows.net/', 'silver_path': 'abfss://silver@adlsnikhildev.dfs.core.windows.net/', 'gold_path': 'abfss://gold@adlsnikhildev.dfs.core.windows.net/'}
